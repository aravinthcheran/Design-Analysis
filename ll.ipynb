# %%
class node:
    def __init__(self,data=0,next=None):
        self.data = data
        self.next = next

class linked_list:
    def __init__(self):
        self.head = None

    def append(self,data):
        if self.head is None:
            self.head = node(data)
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = node(data)

    def print_list(self):
        temp = self.head
        while temp:
            print(temp.data)
            temp = temp.next
        
def rotateRight( head, k):
        """
        :type head: ListNode
        :type k: int
        :rtype: ListNode
        """
        if not head:
            return None
        
        # Find the length of the linked list
        length = 2
        tail = head.next
        while tail.next:
            length += 1
            tail = tail.next
        
        # Adjust k to perform rotation modulo the length of the linked list
        k %= length
        
        # If k is 0, no rotation needed
        if k == 0:
            return head
        
        # Find the new tail node after rotation
        new_tail_index = length - k - 1
        new_tail = head
        for _ in range(new_tail_index):
            new_tail = new_tail.next
        
        # Perform rotation
        new_head = new_tail.next
        new_tail.next = None
        tail.next = head
        
        return new_head
def print_list(self):
        temp = self
        while temp:
            print(temp.data)
            temp = temp.next




n1=linked_list()
n1.append(1)
n1.append(2)
n1.append(3)
n1.append(4)
n1.append(5)
# n1.print_list()
n2=linked_list()
n2=rotateRight(n1.head,2)
print_list(n2)
# Out:
# 4
# 5
# 1
# 2
# 3
